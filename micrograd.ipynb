# %% [markdown]
# ## 1. 미분이란 — 수치미분으로 기울기 재보기

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 3*x**2 -4*x + 5

# %%
f(3.0)
# Out:
# 20.0

# %%
xs = np.arange(-5,5,0.25)
ys = f(xs)
plt.plot(xs,ys)

# %%
h = 0.00000001
x = 3.0
(f(x+h)-f(x))/h
# Out:
# 14.00000009255109

# %%
h = 0.00000001
x = -3.0
(f(x+h)-f(x))/h
# Out:
# -22.00000039920269

# %%
h = 0.0001

a = 2.0
b = -3.0
c = 10.0

d1 = a*b + c
a += h
d2 = a*b + c

print('d1',d1)
print('d2',d2)
print('slope',(d2-d1)/h)
# Out:
# d1 4.0
# d2 3.999699999999999
# slope -3.000000000010772
